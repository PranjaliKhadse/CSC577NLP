# %% [markdown]
# #### Applied Data Science Capstone: Neighborhoods in Toronto - Part 1 & Part 2

# %% [markdown]
# ## Part1

# %% [markdown]
# ###### 1. Import all required libraries

# %%
# Import necessary libraries

import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

import json # library to handle JSON files

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from bs4 import BeautifulSoup # library to parse HTML and XML documents

from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

import folium # map rendering library

# %% [markdown]
# ###### 2. Use beautiful soup to scrape data

# %%
# send the GET request
data = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text

# %%
# parse data from the html into a beautifulsoup object
soup = BeautifulSoup(data, 'html.parser')

# %%
# create three lists to store table data
postalCodeList = []
boroughList = []
neighborhoodList = []

# %%
# append the data into the respective lists
for row in soup.find('table').find_all('tr'):
    cells = row.find_all('td')
    if(len(cells) > 0):
        postalCodeList.append(cells[0].text)
        boroughList.append(cells[1].text)
        neighborhoodList.append(cells[2].text.rstrip('\n')) # avoid new lines in neighborhood cell

# %%
# create a new DataFrame from the three lists
toronto_df = pd.DataFrame({"PostalCode": postalCodeList,
                           "Borough": boroughList,
                           "Neighborhood": neighborhoodList})

toronto_df.head()
# Out:
#   PostalCode             Borough                Neighborhood
# 0      M1A\n      Not assigned\n
# 1      M2A\n      Not assigned\n
# 2      M3A\n        North York\n                   Parkwoods
# 3      M4A\n        North York\n            Victoria Village
# 4      M5A\n  Downtown Toronto\n  Regent Park / Harbourfront

# %% [markdown]
# ##### 3. Drop cell with "Not assigned" value

# %%
# drop cells with a borough that is Not assigned
toronto_df_dropna = toronto_df[toronto_df.Borough != "Not assigned"].reset_index(drop=True)
toronto_df_dropna.head()
# Out:
#   PostalCode             Borough                Neighborhood
# 0      M1A\n      Not assigned\n
# 1      M2A\n      Not assigned\n
# 2      M3A\n        North York\n                   Parkwoods
# 3      M4A\n        North York\n            Victoria Village
# 4      M5A\n  Downtown Toronto\n  Regent Park / Harbourfront

# %%
# drop cells with a borough that is Not assigned
toronto_df_dropna = toronto_df[toronto_df.Borough != "Not assigned"].reset_index(drop=True)
toronto_df_dropna.head()
# Out:
#   PostalCode             Borough                Neighborhood
# 0      M1A\n      Not assigned\n
# 1      M2A\n      Not assigned\n
# 2      M3A\n        North York\n                   Parkwoods
# 3      M4A\n        North York\n            Victoria Village
# 4      M5A\n  Downtown Toronto\n  Regent Park / Harbourfront

# %%
toronto_df_grouped = toronto_df_dropna.groupby(["PostalCode", "Borough"], as_index=False).agg(lambda x: ", ".join(x))
toronto_df_grouped.head()
# Out:
#   PostalCode         Borough                              Neighborhood
# 0      M1A\n  Not assigned\n
# 1      M1B\n   Scarborough\n                           Malvern / Rouge
# 2      M1C\n   Scarborough\n  Rouge Hill / Port Union / Highland Creek
# 3      M1E\n   Scarborough\n       Guildwood / Morningside / West Hill
# 4      M1G\n   Scarborough\n                                    Woburn

# %%
toronto_df_grouped.drop(toronto_df_grouped[ toronto_df_grouped['Borough'] == 'Not assigned\n' ].index , inplace=True)

# %%
toronto_df_grouped.head()
# Out:
#   PostalCode        Borough                              Neighborhood
# 1      M1B\n  Scarborough\n                           Malvern / Rouge
# 2      M1C\n  Scarborough\n  Rouge Hill / Port Union / Highland Creek
# 3      M1E\n  Scarborough\n       Guildwood / Morningside / West Hill
# 4      M1G\n  Scarborough\n                                    Woburn
# 5      M1H\n  Scarborough\n                                 Cedarbrae

# %% [markdown]
# ###### 4. strip /n from data

# %%
#grouping neighbourhood in sme borough
toronto_df_grouped= toronto_df_grouped.replace('\n',' ', regex=True)
toronto_df_grouped.head()
# Out:
#   PostalCode       Borough                              Neighborhood
# 1       M1B   Scarborough                            Malvern / Rouge
# 2       M1C   Scarborough   Rouge Hill / Port Union / Highland Creek
# 3       M1E   Scarborough        Guildwood / Morningside / West Hill
# 4       M1G   Scarborough                                     Woburn
# 5       M1H   Scarborough                                  Cedarbrae

# %%
# for Neighborhood="Not assigned", make the value the same as Borough
for index, row in toronto_df_grouped.iterrows():
    if row["Neighborhood"] == "Not assigned":
        row["Neighborhood"] = row["Borough"]
        
toronto_df_grouped.head()
# Out:
#   PostalCode       Borough                              Neighborhood
# 1       M1B   Scarborough                            Malvern / Rouge
# 2       M1C   Scarborough   Rouge Hill / Port Union / Highland Creek
# 3       M1E   Scarborough        Guildwood / Morningside / West Hill
# 4       M1G   Scarborough                                     Woburn
# 5       M1H   Scarborough                                  Cedarbrae

# %% [markdown]
# ###### 5. Group neighborhood of same borough

# %%
# for Neighborhood="Not assigned", make the value the same as Borough
for index, row in toronto_df_grouped.iterrows():
    if row["Neighborhood"] == "Not assigned":
        row["Neighborhood"] = row["Borough"]
        
toronto_df_grouped.head()
# Out:
#   PostalCode       Borough                              Neighborhood
# 1       M1B   Scarborough                            Malvern / Rouge
# 2       M1C   Scarborough   Rouge Hill / Port Union / Highland Creek
# 3       M1E   Scarborough        Guildwood / Morningside / West Hill
# 4       M1G   Scarborough                                     Woburn
# 5       M1H   Scarborough                                  Cedarbrae

# %% [markdown]
# ###### 6. Number of rows in dataframe

# %%
# print the number of rows of the cleaned dataframe
toronto_df_grouped.shape
# Out:
# (103, 3)

# %% [markdown]
# ## Part 2

# %% [markdown]
# ###### 7. Load csv file with coordinates from  Coursera

# %%
# load the coordinates from the csv file on Coursera
coordinates = pd.read_csv("Geospatial_Coordinates.csv")
coordinates.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# ###### 8. Merge two csv data

# %%
Merged_data = toronto_df_grouped.join(coordinates)
Merged_data
# Out:
#     PostalCode            Borough  \
# 1         M1B        Scarborough
# 2         M1C        Scarborough
# 3         M1E        Scarborough
# 4         M1G        Scarborough
# 5         M1H        Scarborough
# 6         M1J        Scarborough
# 7         M1K        Scarborough
# 8         M1L        Scarborough
# 9         M1M        Scarborough
# 10        M1N        Scarborough
# 11        M1P        Scarborough
# 12        M1R        Scarborough
# 13        M1S        Scarborough
# 14        M1T        Scarborough
# 15        M1V        Scarborough
# 16        M1W        Scarborough
# 17        M1X        Scarborough
# 25        M2H         North York
# 26        M2J         North York
# 27        M2K         North York
# 28        M2L         North York
# 29        M2M         North York
# 30        M2N         North York
# 31        M2P         North York
# 32        M2R         North York
# 40        M3A         North York
# 41        M3B         North York
# 42        M3C         North York
# 45        M3H         North York
# 46        M3J         North York
# 47        M3K         North York
# 48        M3L         North York
# 49        M3M         North York
# 50        M3N         North York
# 60        M4A         North York
# 61        M4B          East York
# 62        M4C          East York
# 63        M4E       East Toronto
# 64        M4G          East York
# 65        M4H          East York
# 66        M4J          East York
# 67        M4K       East Toronto
# 68        M4L       East Toronto
# 69        M4M       East Toronto
# 70        M4N    Central Toronto
# 71        M4P    Central Toronto
# 72        M4R    Central Toronto
# 73        M4S    Central Toronto
# 74        M4T    Central Toronto
# 75        M4V    Central Toronto
# 76        M4W   Downtown Toronto
# 77        M4X   Downtown Toronto
# 78        M4Y   Downtown Toronto
# 80        M5A   Downtown Toronto
# 81        M5B   Downtown Toronto
# 82        M5C   Downtown Toronto
# 83        M5E   Downtown Toronto
# 84        M5G   Downtown Toronto
# 85        M5H   Downtown Toronto
# 86        M5J   Downtown Toronto
# 87        M5K   Downtown Toronto
# 88        M5L   Downtown Toronto
# 89        M5M         North York
# 90        M5N    Central Toronto
# 91        M5P    Central Toronto
# 92        M5R    Central Toronto
# 93        M5S   Downtown Toronto
# 94        M5T   Downtown Toronto
# 95        M5V   Downtown Toronto
# 96        M5W   Downtown Toronto
# 97        M5X   Downtown Toronto
# 100       M6A         North York
# 101       M6B         North York
# 102       M6C               York
# 103       M6E               York
# 104       M6G   Downtown Toronto
# 105       M6H       West Toronto
# 106       M6J       West Toronto
# 107       M6K       West Toronto
# 108       M6L         North York
# 109       M6M               York
# 110       M6N               York
# 111       M6P       West Toronto
# 112       M6R       West Toronto
# 113       M6S       West Toronto
# 120       M7A   Downtown Toronto
# 132       M7R        Mississauga
# 138       M7Y       East Toronto
# 155       M8V          Etobicoke
# 156       M8W          Etobicoke
# 157       M8X          Etobicoke
# 158       M8Y          Etobicoke
# 159       M8Z          Etobicoke
# 160       M9A          Etobicoke
# 161       M9B          Etobicoke
# 162       M9C          Etobicoke
# 168       M9L         North York
# 169       M9M         North York
# 170       M9N               York
# 171       M9P          Etobicoke
# 172       M9R          Etobicoke
# 175       M9V          Etobicoke
# 176       M9W          Etobicoke
#
#                                           Neighborhood Postal Code   Latitude  \
# 1                                      Malvern / Rouge         M1C  43.784535
# 2             Rouge Hill / Port Union / Highland Creek         M1E  43.763573
# 3                  Guildwood / Morningside / West Hill         M1G  43.770992
# 4                                               Woburn         M1H  43.773136
# 5                                            Cedarbrae         M1J  43.744734
# 6                                  Scarborough Village         M1K  43.727929
# 7        Kennedy Park / Ionview / East Birchmount Park         M1L  43.711112
# 8                    Golden Mile / Clairlea / Oakridge         M1M  43.716316
# 9    Cliffside / Cliffcrest / Scarborough Village West         M1N  43.692657
# 10                        Birch Cliff / Cliffside West         M1P  43.757410
# 11   Dorset Park / Wexford Heights / Scarborough To...         M1R  43.750072
# 12                                  Wexford / Maryvale         M1S  43.794200
# 13                                           Agincourt         M1T  43.781638
# 14           Clarks Corners / Tam O'Shanter / Sullivan         M1V  43.815252
# 15   Milliken / Agincourt North / Steeles East / L'...         M1W  43.799525
# 16                      Steeles West / L'Amoreaux West         M1X  43.836125
# 17                                         Upper Rouge         M2H  43.803762
# 25                                   Hillcrest Village         M3A  43.753259
# 26                      Fairview / Henry Farm / Oriole         M3B  43.745906
# 27                                     Bayview Village         M3C  43.725900
# 28                           York Mills / Silver Hills         M3H  43.754328
# 29                            Willowdale / Newtonbrook         M3J  43.767980
# 30                                          Willowdale         M3K  43.737473
# 31                                     York Mills West         M3L  43.739015
# 32                                          Willowdale         M3M  43.728496
# 40                                           Parkwoods         M4J  43.685347
# 41                                           Don Mills         M4K  43.679557
# 42                                           Don Mills         M4L  43.668999
# 45   Bathurst Manor / Wilson Heights / Downsview North         M4P  43.712751
# 46                    Northwood Park / York University         M4R  43.715383
# 47                                           Downsview         M4S  43.704324
# 48                                           Downsview         M4T  43.689574
# 49                                           Downsview         M4V  43.686412
# 50                                           Downsview         M4W  43.679563
# 60                                    Victoria Village         M5K  43.647177
# 61                    Parkview Hill / Woodbine Gardens         M5L  43.648198
# 62                                    Woodbine Heights         M5M  43.733283
# 63                                         The Beaches         M5N  43.711695
# 64                                             Leaside         M5P  43.696948
# 65                                    Thorncliffe Park         M5R  43.672710
# 66                                        East Toronto         M5S  43.662696
# 67                       The Danforth West / Riverdale         M5T  43.653206
# 68                     India Bazaar / The Beaches West         M5V  43.628947
# 69                                     Studio District         M5W  43.646435
# 70                                       Lawrence Park         M5X  43.648429
# 71                                    Davisville North         M6A  43.718518
# 72                                  North Toronto West         M6B  43.709577
# 73                                          Davisville         M6C  43.693781
# 74                        Moore Park / Summerhill East         M6E  43.689026
# 75   Summerhill West / Rathnelly / South Hill / For...         M6G  43.669542
# 76                                            Rosedale         M6H  43.669005
# 77                        St. James Town / Cabbagetown         M6J  43.647927
# 78                                Church and Wellesley         M6K  43.636847
# 80                          Regent Park / Harbourfront         M6M  43.691116
# 81                            Garden District, Ryerson         M6N  43.673185
# 82                                      St. James Town         M6P  43.661608
# 83                                         Berczy Park         M6R  43.648960
# 84                                  Central Bay Street         M6S  43.651571
# 85                          Richmond / Adelaide / King         M7A  43.662301
# 86   Harbourfront East / Union Station / Toronto Is...         M7R  43.636966
# 87           Toronto Dominion Centre / Design Exchange         M7Y  43.662744
# 88                     Commerce Court / Victoria Hotel         M8V  43.605647
# 89                  Bedford Park / Lawrence Manor East         M8W  43.602414
# 90                                            Roselawn         M8X  43.653654
# 91                            Forest Hill North & West         M8Y  43.636258
# 92               The Annex / North Midtown / Yorkville         M8Z  43.628841
# 93                     University of Toronto / Harbord         M9A  43.667856
# 94         Kensington Market / Chinatown / Grange Park         M9B  43.650943
# 95   CN Tower / King and Spadina / Railway Lands / ...         M9C  43.643515
# 96                                      Stn A PO Boxes         M9L  43.756303
# 97             First Canadian Place / Underground city         M9M  43.724766
# 100                  Lawrence Manor / Lawrence Heights         M9R  43.688905
# 101                                          Glencairn         M9V  43.739416
# 102                                 Humewood-Cedarvale         M9W  43.706748
# 103                                Caledonia-Fairbanks         NaN        NaN
# 104                                           Christie         NaN        NaN
# 105                      Dufferin / Dovercourt Village         NaN        NaN
# 106                          Little Portugal / Trinity         NaN        NaN
# 107     Brockton / Parkdale Village / Exhibition Place         NaN        NaN
# 108         North Park / Maple Leaf Park / Upwood Park         NaN        NaN
# 109  Del Ray / Mount Dennis / Keelsdale and Silvert...         NaN        NaN
# 110                     Runnymede / The Junction North         NaN        NaN
# 111                     High Park / The Junction South         NaN        NaN
# 112                            Parkdale / Roncesvalles         NaN        NaN
# 113                                Runnymede / Swansea         NaN        NaN
# 120       Queen's Park / Ontario Provincial Government         NaN        NaN
# 132              Canada Post Gateway Processing Centre         NaN        NaN
# 138              Business reply mail Processing CentrE         NaN        NaN
# 155     New Toronto / Mimico South / Humber Bay Shores         NaN        NaN
# 156                            Alderwood / Long Branch         NaN        NaN
# 157   The Kingsway / Montgomery Road  / Old Mill North         NaN        NaN
# 158  Old Mill South / King's Mill Park / Sunnylea /...         NaN        NaN
# 159  Mimico NW / The Queensway West / South of Bloo...         NaN        NaN
# 160                                   Islington Avenue         NaN        NaN
# 161  West Deane Park / Princess Gardens / Martin Gr...         NaN        NaN
# 162  Eringate / Bloordale Gardens / Old Burnhamthor...         NaN        NaN
# 168                                      Humber Summit         NaN        NaN
# 169                                  Humberlea / Emery         NaN        NaN
# 170                                             Weston         NaN        NaN
# 171                                          Westmount         NaN        NaN
# 172  Kingsview Village / St. Phillips / Martin Grov...         NaN        NaN
# 175  South Steeles / Silverstone / Humbergate / Jam...         NaN        NaN
# 176                                          Northwest         NaN        NaN
#
#      Longitude
# 1   -79.160497
# 2   -79.188711
# 3   -79.216917
# 4   -79.239476
# 5   -79.239476
# 6   -79.262029
# 7   -79.284577
# 8   -79.239476
# 9   -79.264848
# 10  -79.273304
# 11  -79.295849
# 12  -79.262029
# 13  -79.304302
# 14  -79.284577
# 15  -79.318389
# 16  -79.205636
# 17  -79.363452
# 25  -79.329656
# 26  -79.352188
# 27  -79.340923
# 28  -79.442259
# 29  -79.487262
# 30  -79.464763
# 31  -79.506944
# 32  -79.495697
# 40  -79.338106
# 41  -79.352188
# 42  -79.315572
# 45  -79.390197
# 46  -79.405678
# 47  -79.388790
# 48  -79.383160
# 49  -79.400049
# 50  -79.377529
# 60  -79.381576
# 61  -79.379817
# 62  -79.419750
# 63  -79.416936
# 64  -79.411307
# 65  -79.405678
# 66  -79.400049
# 67  -79.400049
# 68  -79.394420
# 69  -79.374846
# 70  -79.382280
# 71  -79.464763
# 72  -79.445073
# 73  -79.428191
# 74  -79.453512
# 75  -79.422564
# 76  -79.442259
# 77  -79.419750
# 78  -79.428191
# 80  -79.476013
# 81  -79.487262
# 82  -79.464763
# 83  -79.456325
# 84  -79.484450
# 85  -79.389494
# 86  -79.615819
# 87  -79.321558
# 88  -79.501321
# 89  -79.543484
# 90  -79.506944
# 91  -79.498509
# 92  -79.520999
# 93  -79.532242
# 94  -79.554724
# 95  -79.577201
# 96  -79.565963
# 97  -79.532242
# 100 -79.554724
# 101 -79.588437
# 102 -79.594054
# 103        NaN
# 104        NaN
# 105        NaN
# 106        NaN
# 107        NaN
# 108        NaN
# 109        NaN
# 110        NaN
# 111        NaN
# 112        NaN
# 113        NaN
# 120        NaN
# 132        NaN
# 138        NaN
# 155        NaN
# 156        NaN
# 157        NaN
# 158        NaN
# 159        NaN
# 160        NaN
# 161        NaN
# 162        NaN
# 168        NaN
# 169        NaN
# 170        NaN
# 171        NaN
# 172        NaN
# 175        NaN
# 176        NaN

# %%
# save data to csv file
Merged_data.to_csv(r'df_cord.csv',index=False)
